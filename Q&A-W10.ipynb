# %% [markdown]
# # Q&A Activity Question Week -10

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### (1) Load the data into the pandas environment and identify some basic details of the dataset

# %%
#Reading data

data=pd.read_csv("employee.csv")
data
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 1        S Kumar   NaN  16000.0      F     Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F       Sales    G3                556
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# 5  Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# 6   James Authur  54.0      NaN      F  Operations    G3                 53
# 7     Josh Wills  54.0  52000.0      F     Finance    G3                901
# 8       Leo Duck  23.0  98000.0      M       Sales    G4                709

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9 non-null      object
#  1   age                7 non-null      float64
#  2   income             7 non-null      float64
#  3   gender             7 non-null      object
#  4   department         9 non-null      object
#  5   grade              9 non-null      object
#  6   performance_score  9 non-null      int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 632.0+ bytes

# %% [markdown]
# ### (2) Reset the index as "name" as the index

# %%
data=data.set_index(['name'])
data
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# James Authur   54.0      NaN      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# ### 3 Select rows for specific names Jack Morgan and Josh wills.

# %%
data.loc[['Jack Morgan', 'Josh Wills']]
# Out:
#               age   income gender department grade  performance_score
# name
# Jack Morgan  32.0  35000.0      M    Finance    G2                674
# Josh Wills   54.0  52000.0      F    Finance    G3                901

# %% [markdown]
# ### 4 Select data for multiple values "Sales" and “Finance”.

# %%
data.loc[(data['department'] == 'Sales') | (data['department'] == 'Finance')]
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649
# Josh Wills     54.0  52000.0      F    Finance    G3                901
# Leo Duck       23.0  98000.0      M      Sales    G4                709

# %% [markdown]
# ### 5 Display employee who has more than 700 performance score.

# %%
data.loc[data['performance_score']>700]
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# ### 6 Display employee who has more than 500 and less than 700 performance score

# %%
data.loc[(data['performance_score'] >500) & (data['performance_score']<700)]
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649

# %% [markdown]
# ### 7 Check and handle missing values in the dataset.

# %%
data.isna().sum()
# Out:
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
data.dtypes
# Out:
# age                  float64
# income               float64
# gender                object
# department            object
# grade                 object
# performance_score      int64
# dtype: object

# %%
mean_value=data['age'].mean()
data['age']=round(data['age'].fillna(mean_value))

# %%
data
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar        40.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  40.0  62000.0    NaN       Sales    G3                649
# James Authur   54.0      NaN      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %%
median_value=data['income'].median()
data['income']=data['income'].fillna(median_value)
data
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0  52000.0    NaN  Operations    G3                723
# S Kumar        40.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  40.0  62000.0    NaN       Sales    G3                649
# James Authur   54.0  52000.0      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %%
mode_value=data['gender'].mode()[0]
data['gender']=data['gender'].fillna(mode_value)
data
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0  52000.0      F  Operations    G3                723
# S Kumar        40.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  40.0  62000.0      F       Sales    G3                649
# James Authur   54.0  52000.0      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# ### 8 Check the outliers and handle outliers in performance score using Percentiles.

# %%
plt.boxplot(data['performance_score'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dee67bf8e0>,
#   <matplotlib.lines.Line2D at 0x1dee67bfbb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1dee67bff40>,
#   <matplotlib.lines.Line2D at 0x1dee6e7e310>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1dee67bf490>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dee6e7e6a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dee6e7ea30>],
#  'means': []}

# %%
Q1 = np.percentile(data['performance_score'], 25, interpolation = 'midpoint')
Q2 = np.percentile(data['performance_score'], 50, interpolation = 'midpoint')
Q3 = np.percentile(data['performance_score'], 75, interpolation = 'midpoint')

# %%
print (Q1)
print (Q2)
print (Q3)
# Out:
# 556.0
# 674.0
# 711.0

# %%
IQR=Q3-Q1
low_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
print (low_limit)
print (upper_limit)
# Out:
# 323.5
# 943.5

# %%
outlier=[]
for x in data['performance_score']:
    if((x>upper_limit) or (x<low_limit)):
       outlier.append(x)

# %%
outlier
# Out:
# [53]

# %%
ind1=data['performance_score']<low_limit
data.loc[ind1].index
# Out:
# Index(['James Authur'], dtype='object', name='name')

# %%
data.drop(['James Authur'],inplace=True)
plt.boxplot(data['performance_score'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dee72d4340>,
#   <matplotlib.lines.Line2D at 0x1dee72d46d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1dee72d4a00>,
#   <matplotlib.lines.Line2D at 0x1dee72d4cd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1dee72c3fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dee72d4fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dee72e1370>],
#  'means': []}

# %%
data
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0  52000.0      F  Operations    G3                723
# S Kumar        40.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  40.0  62000.0      F       Sales    G3                649
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# ### 9 Check the gender column and do Dummy encoding.

# %%
data.gender.nunique()
# Out:
# 2

# %%
data=pd.get_dummies(data,columns=['gender'])

# %%
data
# Out:
#                 age   income  department grade  performance_score  gender_F  \
# name
# Allen Smith    45.0  52000.0  Operations    G3                723         1
# S Kumar        40.0  16000.0     Finance    G0                520         1
# Jack Morgan    32.0  35000.0     Finance    G2                674         0
# Ying Chin      45.0  65000.0       Sales    G3                556         1
# Dheeraj Patel  30.0  42000.0  Operations    G2                711         1
# Satyam Sharma  40.0  62000.0       Sales    G3                649         1
# Josh Wills     54.0  52000.0     Finance    G3                901         1
# Leo Duck       23.0  98000.0       Sales    G4                709         0
#
#                gender_M
# name
# Allen Smith           0
# S Kumar               0
# Jack Morgan           1
# Ying Chin             0
# Dheeraj Patel         0
# Satyam Sharma         0
# Josh Wills            0
# Leo Duck              1

# %% [markdown]
# ### 10 Do the standard scaling on the feature performance score

# %%
from sklearn import preprocessing

# %%
x=data['performance_score']
x.describe()
# Out:
# count      8.00000
# mean     680.37500
# std      116.16729
# min      520.00000
# 25%      625.75000
# 50%      691.50000
# 75%      714.00000
# max      901.00000
# Name: performance_score, dtype: float64

# %%
stand=preprocessing.StandardScaler()
x=pd.DataFrame(x)
x=stand.fit_transform(x)
x
# Out:
# array([[ 0.39226224],
#        [-1.47587231],
#        [-0.05866679],
#        [-1.14457751],
#        [ 0.28183064],
#        [-0.28873262],
#        [ 2.03033096],
#        [ 0.26342538]])

# %%
x=pd.DataFrame(x)
x.describe()
# Out:
#                   0
# count  8.000000e+00
# mean   4.857226e-17
# std    1.069045e+00
# min   -1.475872e+00
# 25%   -5.026938e-01
# 50%    1.023793e-01
# 75%    3.094385e-01
# max    2.030331e+00
